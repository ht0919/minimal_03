# %% [markdown]
# # [k-means++] 英語と数学の試験結果から新入生をクラス分けする
# Copyright © 2022 田中裕行 All rights reserved.

# %% [markdown]
# ## (1) クラス分けするデータを用意する

# %%
import random
import pandas as pd

math    = [] # 数学の得点用リスト
english = [] # 英語の得点用リスト

random.seed(0)
for _ in range(30): # 30人分のデータを作成
    math.append(random.randint(0, 100))    # 数学の得点を0～100まで乱数で生成
    english.append(random.randint(0, 100)) # 英語の得点を0～100まで乱数で生成

df = pd.DataFrame({'math':math, 'english':english}) # pandasのデータフレームに変換
df
# Out:
#     math  english
# 0     49       97
# 1     53        5
# 2     33       65
# 3     62       51
# 4    100       38
# 5     61       45
# 6     74       27
# 7     64       17
# 8     36       17
# 9     96       12
# 10    79       32
# 11    68       90
# 12    77       18
# 13    39       12
# 14    93        9
# 15    87       42
# 16    60       71
# 17    12       45
# 18    55       40
# 19    78       81
# 20    26       70
# 21    61       56
# 22    66       33
# 23     7       70
# 24     1       11
# 25    92       51
# 26    90      100
# 27    85       80
# 28     0       78
# 29    63       42

# %% [markdown]
# ## (2) データの内訳を確認する

# %%
# データの件数、平均、標準偏差等を一括表示する
df.describe()
# Out:
#              math     english
# count   30.000000   30.000000
# mean    58.900000   46.833333
# std     28.658934   28.185449
# min      0.000000    5.000000
# 25%     41.500000   20.250000
# 50%     62.500000   43.500000
# 75%     78.750000   70.000000
# max    100.000000  100.000000

# %% [markdown]
# ## (3) グラフで視覚化する

# %%
import matplotlib.pyplot as plt

# 数学と英語の得点を散布図で出力
plt.scatter(math, english)
plt.xlabel('math')
plt.ylabel('english')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## (4) 機械にクラス分けさせる

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=4, random_state=0, init='k-means++')
cls_data = df.copy()
model.fit(cls_data)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %% [markdown]
# ## (5) 中心点の座標を確認する

# %%
cluster_center = pd.DataFrame(model.cluster_centers_)
cluster_center.columns = cls_data.columns[:2]
cluster_center
# Out:
#         math  english
# 0  75.333333    34.20
# 1  15.600000    65.60
# 2  71.666667    86.50
# 3  32.250000    11.25

# %% [markdown]
# ## (6) クラス分けした結果をグラフで表示する

# %%
# クラス分けしたデータを散布図で描画
plt.scatter(cls_data['math'], cls_data['english'], c=model.labels_)
plt.xlabel('math')
plt.ylabel('english')

# 中心点を赤い星マークで描画
plt.scatter(cluster_center['math'], cluster_center['english'], marker='*', color='red')

# %% [markdown]
# ## (7) クラス分けした結果の内訳を表示する

# %%
import numpy as np

# クラス分けした結果のリストを出力
result = model.predict(df)
print(result)

# クラス分けした結果の内訳を出力
print('Aクラス：{}名'.format(np.count_nonzero(result == 0)))
print('Bクラス：{}名'.format(np.count_nonzero(result == 1)))
print('Cクラス：{}名'.format(np.count_nonzero(result == 2)))
print('Dクラス：{}名'.format(np.count_nonzero(result == 3)))
# Out:
# [2 3 1 0 0 0 0 0 3 0 0 2 0 3 0 0 2 1 0 2 1 0 0 1 3 0 2 2 1 0]
# Aクラス：15名
# Bクラス：5名
# Cクラス：6名
# Dクラス：4名

# %% [markdown]
# ## (8) クラス分けした結果の詳細を表示する

# %%
# 受験生ごとのクラス名を表示する
cls = {0:'A', 1:'B', 2:'C', 3:'D'}
test_no = 1
for r in result:
  print('受験番号:{:03d} -> {}クラス'.format(test_no, cls.get(r)))
  test_no += 1
# Out:
# 受験番号:001 -> Cクラス
# 受験番号:002 -> Dクラス
# 受験番号:003 -> Bクラス
# 受験番号:004 -> Aクラス
# 受験番号:005 -> Aクラス
# 受験番号:006 -> Aクラス
# 受験番号:007 -> Aクラス
# 受験番号:008 -> Aクラス
# 受験番号:009 -> Dクラス
# 受験番号:010 -> Aクラス
# 受験番号:011 -> Aクラス
# 受験番号:012 -> Cクラス
# 受験番号:013 -> Aクラス
# 受験番号:014 -> Dクラス
# 受験番号:015 -> Aクラス
# 受験番号:016 -> Aクラス
# 受験番号:017 -> Cクラス
# 受験番号:018 -> Bクラス
# 受験番号:019 -> Aクラス
# 受験番号:020 -> Cクラス
# 受験番号:021 -> Bクラス
# 受験番号:022 -> Aクラス
# 受験番号:023 -> Aクラス
# 受験番号:024 -> Bクラス
# 受験番号:025 -> Dクラス
# 受験番号:026 -> Aクラス
# 受験番号:027 -> Cクラス
# 受験番号:028 -> Cクラス
# 受験番号:029 -> Bクラス
# 受験番号:030 -> Aクラス
